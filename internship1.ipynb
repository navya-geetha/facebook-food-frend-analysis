# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
df=pd.read_csv('/content/Students Data.csv')

# %%
df.columns
# Out:
# Index(['Timestamp', 'Username', 'Name', 'Age', 'Gender', 'City',
#        'College Name', 'Branch', 'Current Year of Study', 'Passed Out Year',
#        'SSC CGPA', 'Intermediate / Diploma CGPA', 'Current CGPA',
#        'Number of Backlogs (if any)', 'Interested Domain',
#        'Python Skill Level', 'SQL Skill Level', 'Programming Languages Known',
#        'Tools Known', 'Do you take online courses (Coursera, Udemy, etc.)?',
#        'Number of Projects Done', 'Certificates Count', 'GitHub Profile Link',
#        'Personal Portfolio Website', 'Learning Mode Preference',
#        'Self Learning Hours per Week', 'Average Daily Study Hours',
#        'Average Daily Screen Time', 'Next Interested Workshop',
#        'Do you have a mentor for technical/career guidance?',
#        'Expected Placement Package (LPA)', 'Preferred Job Role',
#        'Are you planning for higher studies?',
#        'Rate your communication skills', 'Aptitude Skill Level',
# ...

# %%
df.columns = df.columns.str.strip()

# %%
plt.figure()
df["Gender"].value_counts().plot(kind='bar')
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
plt.figure()
plt.plot(df["Rate your communication skills"])
plt.title("Communication Skills Trend")
plt.xlabel("Student Index")
plt.ylabel("Communication Skills Rating")
plt.show()

# %%
plt.figure()
plt.scatter(df["Average Daily Study Hours"],
            df["Rate your communication skills"])
plt.title("Study Hours vs Communication Skills")
plt.xlabel("Average Daily Study Hours")
plt.ylabel("Communication Skills Rating")
plt.show()

# %%
numeric_df = df.select_dtypes(include=np.number)

corr_matrix = numeric_df.corr()

plt.figure()
plt.imshow(corr_matrix)
plt.title("Correlation Heatmap")
plt.xticks(range(len(corr_matrix.columns)),
           corr_matrix.columns, rotation=90)
plt.yticks(range(len(corr_matrix.columns)),
           corr_matrix.columns)
plt.colorbar()
plt.show()
